# %% [markdown]
# <a href="https://colab.research.google.com/github/Vivek-afk81/NLP-101/blob/main/NLTK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    from google.colab import drive
    drive.mount("/content/drive")
except ModuleNotFoundError:
    print(" Not running in Google Colab. Skipping drive mount.")
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/My Drive/nlp/data")

# %% [markdown]
# # 4 major uses of nltk
# -  a. Tokenization
# -  b. Stopword removal
# -  c. Stemming
# -  d. Lemmatization

# %%
import nltk
nltk.download("punkt_tab")
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# for tokenize
from nltk.tokenize import word_tokenize
from nltk .corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

# Second import sklearn dependencies
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %%
with open("Movie-Reviews.txt","r",encoding="utf-8") as f:
  raw_text=f.read()
print(raw_text[:200])
# Out:
# When your main character in a superhero movie is unwatchable, you already have a problem. In addition, Captain Marvel has no weaknesses, which kills the tension immediately.
# Her performance was forced

# %% [markdown]
# ###Step-1: Lowercase

# %%
text=raw_text.lower()
print(text[:200])
# Out:
# when your main character in a superhero movie is unwatchable, you already have a problem. in addition, captain marvel has no weaknesses, which kills the tension immediately.
# her performance was forced

# %% [markdown]
# ### Step-2: Tokenization

# %%
tokens=word_tokenize(text)
print("Tokens : ",tokens[:200])
# Out:
# Tokens :  ['when', 'your', 'main', 'character', 'in', 'a', 'superhero', 'movie', 'is', 'unwatchable', ',', 'you', 'already', 'have', 'a', 'problem', '.', 'in', 'addition', ',', 'captain', 'marvel', 'has', 'no', 'weaknesses', ',', 'which', 'kills', 'the', 'tension', 'immediately', '.', 'her', 'performance', 'was', 'forced', ',', 'uninspiring', 'and', 'flat', '!', 'not', 'looking', 'forward', 'to', 'the', 'next', 'movie', 'with', '``', 'her', "''", 'in', 'it', '....', 'i', 'could', "n't", 'believe', 'how', 'boring', 'this', 'movie', 'was', '.', 'the', 'acting', 'is', 'horrible', ',', 'the', 'action', 'is', 'terrible', ',', 'and', 'captain', 'marvel', 'herself', 'is', 'super', 'cheesy', '.', 'this', 'is', 'the', 'worst', 'marvel', 'movie', 'for', 'me', ',', 'alongside', 'ant', 'man', 'and', 'the', 'wasp', 'nothing', 'beats', 'a', 'good', 'marvel', 'movie', ',', 'and', 'this', 'is', 'definitely', 'a', 'good', 'marvel', 'movie', 'this', 'movie', 'did', 'for', 'marvel', 'what', 'wonder', 'woman', 'did', 'for', 'dc', '.', 'captain', 'marvel', 'is', 'a', 'great', 'role', 'model', 'for', 'young', 'children', '.', 'great', 'to', 'see', 'colson', 'and', 'fury', 'as', 'well', '.', 'loved', 'goose', '.', 'captain', 'marvel', 'just', 'became', 'my', 'favorite', 'superhero', 'of', 'all', 'time', '.', 'this', 'movie', 'was', 'funnier', 'than', 'i', 'expected', 'and', 'all-around', 'great', '.', 'go', 'see', 'it', '!', 'this', 'is', 'a', 'very', 'controversial', 'marvel', 'film', '.', 'which', 'seems', 'to', 'be', 'a', 'running', 'trend', 'with', 'disney', 'films', 'recently', '.', 'unfortunately', ',', 'despite', 'carrying', 'many', 'elements']

# %% [markdown]
# ### Step-3: Remove punctuations

# %%
import string
punc=string.punctuation
print(
    punc
)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
punctuation_filter=[word for word in tokens if word not in punc]
print(punctuation_filter[:200])
# Out:
# ['when', 'your', 'main', 'character', 'in', 'a', 'superhero', 'movie', 'is', 'unwatchable', 'you', 'already', 'have', 'a', 'problem', 'in', 'addition', 'captain', 'marvel', 'has', 'no', 'weaknesses', 'which', 'kills', 'the', 'tension', 'immediately', 'her', 'performance', 'was', 'forced', 'uninspiring', 'and', 'flat', 'not', 'looking', 'forward', 'to', 'the', 'next', 'movie', 'with', '``', 'her', "''", 'in', 'it', '....', 'i', 'could', "n't", 'believe', 'how', 'boring', 'this', 'movie', 'was', 'the', 'acting', 'is', 'horrible', 'the', 'action', 'is', 'terrible', 'and', 'captain', 'marvel', 'herself', 'is', 'super', 'cheesy', 'this', 'is', 'the', 'worst', 'marvel', 'movie', 'for', 'me', 'alongside', 'ant', 'man', 'and', 'the', 'wasp', 'nothing', 'beats', 'a', 'good', 'marvel', 'movie', 'and', 'this', 'is', 'definitely', 'a', 'good', 'marvel', 'movie', 'this', 'movie', 'did', 'for', 'marvel', 'what', 'wonder', 'woman', 'did', 'for', 'dc', 'captain', 'marvel', 'is', 'a', 'great', 'role', 'model', 'for', 'young', 'children', 'great', 'to', 'see', 'colson', 'and', 'fury', 'as', 'well', 'loved', 'goose', 'captain', 'marvel', 'just', 'became', 'my', 'favorite', 'superhero', 'of', 'all', 'time', 'this', 'movie', 'was', 'funnier', 'than', 'i', 'expected', 'and', 'all-around', 'great', 'go', 'see', 'it', 'this', 'is', 'a', 'very', 'controversial', 'marvel', 'film', 'which', 'seems', 'to', 'be', 'a', 'running', 'trend', 'with', 'disney', 'films', 'recently', 'unfortunately', 'despite', 'carrying', 'many', 'elements', 'of', 'previous', 'marvel', 'installments', 'it', 'fails', 'to', 'embody', 'their', 'success', 'due', 'to', 'its', 'questionable', 'ambition', 'it', "'s", 'worth', 'watching', 'just', 'for', 'the', 'fact']

# %% [markdown]
# ### Step-4: Remove stopwords

# %%
eng_stopwords = stopwords.words("english")
filtered_tokens = [word for word in punctuation_filter if word not in eng_stopwords]
print("Removed stopwords:",filtered_tokens)
# Out:
# Removed stopwords: ['main', 'character', 'superhero', 'movie', 'unwatchable', 'already', 'problem', 'addition', 'captain', 'marvel', 'weaknesses', 'kills', 'tension', 'immediately', 'performance', 'forced', 'uninspiring', 'flat', 'looking', 'forward', 'next', 'movie', '``', "''", '....', 'could', "n't", 'believe', 'boring', 'movie', 'acting', 'horrible', 'action', 'terrible', 'captain', 'marvel', 'super', 'cheesy', 'worst', 'marvel', 'movie', 'alongside', 'ant', 'man', 'wasp', 'nothing', 'beats', 'good', 'marvel', 'movie', 'definitely', 'good', 'marvel', 'movie', 'movie', 'marvel', 'wonder', 'woman', 'dc', 'captain', 'marvel', 'great', 'role', 'model', 'young', 'children', 'great', 'see', 'colson', 'fury', 'well', 'loved', 'goose', 'captain', 'marvel', 'became', 'favorite', 'superhero', 'time', 'movie', 'funnier', 'expected', 'all-around', 'great', 'go', 'see', 'controversial', 'marvel', 'film', 'seems', 'running', 'trend', 'disney', 'films', 'recently', 'unfortunately', 'despite', 'carrying', 'many', 'elements', 'previous', 'marvel', 'installments', 'fails', 'embody', 'success', 'due', 'questionable', 'ambition', "'s", 'worth', 'watching', 'fact', 'character', 'appear', 'avangers', 'infinity', 'war', 'part', '2.', "'s", 'great', 'first', 'time', 'viewing', 'would', 'watch', 'nah', 'good', 'motivational', 'little', 'kids', 'comical', 'characters', 'first', 'time', 'viewing', 'good', 'wo', "n't", 'look', 'back']

# %% [markdown]
# ### Step-5: Stemming & Lemmatization

# %%
stem = PorterStemmer()
stem.stem("bought")
# Out:
# 'bought'

# %%
wnet = WordNetLemmatizer()
print("Playing :", wnet.lemmatize("playing","v"))
print("Flying :",wnet.lemmatize("flying","v"))
print("Went :",wnet.lemmatize("went","v"))
print("Bought :",wnet.lemmatize("bought","v"))
# Out:
# Playing : play
# Flying : fly
# Went : go
# Bought : buy

# %%
lemmatized_words = []
for word in filtered_tokens:
    lemmatized_words.append(wnet.lemmatize(word,"v"))

print("Lemmatization:",lemmatized_words)
# Out:
# Lemmatization: ['main', 'character', 'superhero', 'movie', 'unwatchable', 'already', 'problem', 'addition', 'captain', 'marvel', 'weaknesses', 'kill', 'tension', 'immediately', 'performance', 'force', 'uninspiring', 'flat', 'look', 'forward', 'next', 'movie', '``', "''", '....', 'could', "n't", 'believe', 'bore', 'movie', 'act', 'horrible', 'action', 'terrible', 'captain', 'marvel', 'super', 'cheesy', 'worst', 'marvel', 'movie', 'alongside', 'ant', 'man', 'wasp', 'nothing', 'beat', 'good', 'marvel', 'movie', 'definitely', 'good', 'marvel', 'movie', 'movie', 'marvel', 'wonder', 'woman', 'dc', 'captain', 'marvel', 'great', 'role', 'model', 'young', 'children', 'great', 'see', 'colson', 'fury', 'well', 'love', 'goose', 'captain', 'marvel', 'become', 'favorite', 'superhero', 'time', 'movie', 'funnier', 'expect', 'all-around', 'great', 'go', 'see', 'controversial', 'marvel', 'film', 'seem', 'run', 'trend', 'disney', 'film', 'recently', 'unfortunately', 'despite', 'carry', 'many', 'elements', 'previous', 'marvel', 'installments', 'fail', 'embody', 'success', 'due', 'questionable', 'ambition', "'s", 'worth', 'watch', 'fact', 'character', 'appear', 'avangers', 'infinity', 'war', 'part', '2.', "'s", 'great', 'first', 'time', 'view', 'would', 'watch', 'nah', 'good', 'motivational', 'little', 'kid', 'comical', 'character', 'first', 'time', 'view', 'good', 'wo', "n't", 'look', 'back']

# %%
cleaned_text = " ".join(lemmatized_words)
print("Cleaned Text:",cleaned_text)
# Out:
# Cleaned Text: main character superhero movie unwatchable already problem addition captain marvel weaknesses kill tension immediately performance force uninspiring flat look forward next movie `` '' .... could n't believe bore movie act horrible action terrible captain marvel super cheesy worst marvel movie alongside ant man wasp nothing beat good marvel movie definitely good marvel movie movie marvel wonder woman dc captain marvel great role model young children great see colson fury well love goose captain marvel become favorite superhero time movie funnier expect all-around great go see controversial marvel film seem run trend disney film recently unfortunately despite carry many elements previous marvel installments fail embody success due questionable ambition 's worth watch fact character appear avangers infinity war part 2. 's great first time view would watch nah good motivational little kid comical character first time view good wo n't look back

# %% [markdown]
# ###Complete process

# %%
with open("Movie-Reviews.txt", "r", encoding="utf-8") as f:
    raw_text_lines = f.readlines()
print(raw_text_lines)
# Out:
# ['When your main character in a superhero movie is unwatchable, you already have a problem. In addition, Captain Marvel has no weaknesses, which kills the tension immediately.\n', 'Her performance was forced, uninspiring and flat! Not looking forward to the next movie with "her" in it....\n', "I couldn't believe how boring this movie was. The acting is horrible, the action is terrible, and Captain Marvel herself is super cheesy. This is the worst Marvel movie for me, alongside Ant man and the Wasp\n", 'Nothing beats a good marvel movie, and this is definitely a good marvel movie\n', 'This movie did for Marvel what Wonder Woman did for DC. Captain Marvel is a great role model for young children. Great to see Colson and Fury as well. Loved Goose.\n', 'Captain Marvel just became my favorite superhero of all time. This movie was funnier than I expected and all-around great. Go see it!\n', 'This is a very controversial Marvel film. Which seems to be a running trend with Disney films recently.\n', 'Unfortunately, despite carrying many elements of previous Marvel installments, it fails to embody their success due to its questionable ambition. \n', "It's worth watching just for the fact that this character will appear in The Avangers infinity war part 2. \n", "It's great for a first time viewing. Would you watch it again? Nah. A good motivational for little kids with comical characters. First time viewing is good but I won't look back at it."]

# %%
def preprocess_text(raw_text):
    cleaned_sentences = []

    for sentence in raw_text:
        text = sentence.lower()
        print("After Lowercase :", text)

        tokens = word_tokenize(text)
        print("Tokens :", tokens)

        punctuation_filter = [word for word in tokens if word not in punc]
        print("Removed Punctuations:", punctuation_filter)

        eng_stopwords = stopwords.words("english")
        filtered_tokens = [word for word in punctuation_filter if word not in eng_stopwords]
        print("Removed stopwords:", filtered_tokens)

        wnet = WordNetLemmatizer()
        lemmatized_words = []
        for word in filtered_tokens:
            lemmatized_words.append(wnet.lemmatize(word, "v"))

        print("Lemmatization:", lemmatized_words)

        cleaned_text = " ".join(lemmatized_words)
        cleaned_sentences.append(cleaned_text)

        print("=" * 50)

    return cleaned_sentences

# %%
cleaned_text = preprocess_text(raw_text_lines[:200])
# Out:
# After Lowercase : when your main character in a superhero movie is unwatchable, you already have a problem. in addition, captain marvel has no weaknesses, which kills the tension immediately.
#
# Tokens : ['when', 'your', 'main', 'character', 'in', 'a', 'superhero', 'movie', 'is', 'unwatchable', ',', 'you', 'already', 'have', 'a', 'problem', '.', 'in', 'addition', ',', 'captain', 'marvel', 'has', 'no', 'weaknesses', ',', 'which', 'kills', 'the', 'tension', 'immediately', '.']
# Removed Punctuations: ['when', 'your', 'main', 'character', 'in', 'a', 'superhero', 'movie', 'is', 'unwatchable', 'you', 'already', 'have', 'a', 'problem', 'in', 'addition', 'captain', 'marvel', 'has', 'no', 'weaknesses', 'which', 'kills', 'the', 'tension', 'immediately']
# Removed stopwords: ['main', 'character', 'superhero', 'movie', 'unwatchable', 'already', 'problem', 'addition', 'captain', 'marvel', 'weaknesses', 'kills', 'tension', 'immediately']
# Lemmatization: ['main', 'character', 'superhero', 'movie', 'unwatchable', 'already', 'problem', 'addition', 'captain', 'marvel', 'weaknesses', 'kill', 'tension', 'immediately']
# ==================================================
# After Lowercase : her performance was forced, uninspiring and flat! not looking forward to the next movie with "her" in it....
#
# Tokens : ['her', 'performance', 'was', 'forced', ',', 'uninspiring', 'and', 'flat', '!', 'not', 'looking', 'forward', 'to', 'the', 'next', 'movie', 'with', '``', 'her', "''", 'in', 'it', '....']
# Removed Punctuations: ['her', 'performance', 'was', 'forced', 'uninspiring', 'and', 'flat', 'not', 'looking', 'forward', 'to', 'the', 'next', 'movie', 'with', '``', 'her', "''", 'in', 'it', '....']
# Removed stopwords: ['performance', 'forced', 'uninspiring', 'flat', 'looking', 'forward', 'next', 'movie', '``', "''", '....']
# Lemmatization: ['performance', 'force', 'uninspiring', 'flat', 'look', 'forward', 'next', 'movie', '``', "''", '....']
# ==================================================
# After Lowercase : i couldn't believe how boring this movie was. the acting is horrible, the action is terrible, and captain marvel herself is super cheesy. this is the worst marvel movie for me, alongside ant man and the wasp
#
# Tokens : ['i', 'could', "n't", 'believe', 'how', 'boring', 'this', 'movie', 'was', '.', 'the', 'acting', 'is', 'horrible', ',', 'the', 'action', 'is', 'terrible', ',', 'and', 'captain', 'marvel', 'herself', 'is', 'super', 'cheesy', '.', 'this', 'is', 'the', 'worst', 'marvel', 'movie', 'for', 'me', ',', 'alongside', 'ant', 'man', 'and', 'the', 'wasp']
# Removed Punctuations: ['i', 'could', "n't", 'believe', 'how', 'boring', 'this', 'movie', 'was', 'the', 'acting', 'is', 'horrible', 'the', 'action', 'is', 'terrible', 'and', 'captain', 'marvel', 'herself', 'is', 'super', 'cheesy', 'this', 'is', 'the', 'worst', 'marvel', 'movie', 'for', 'me', 'alongside', 'ant', 'man', 'and', 'the', 'wasp']
# Removed stopwords: ['could', "n't", 'believe', 'boring', 'movie', 'acting', 'horrible', 'action', 'terrible', 'captain', 'marvel', 'super', 'cheesy', 'worst', 'marvel', 'movie', 'alongside', 'ant', 'man', 'wasp']
# Lemmatization: ['could', "n't", 'believe', 'bore', 'movie', 'act', 'horrible', 'action', 'terrible', 'captain', 'marvel', 'super', 'cheesy', 'worst', 'marvel', 'movie', 'alongside', 'ant', 'man', 'wasp']
# ==================================================
# After Lowercase : nothing beats a good marvel movie, and this is definitely a good marvel movie
#
# Tokens : ['nothing', 'beats', 'a', 'good', 'marvel', 'movie', ',', 'and', 'this', 'is', 'definitely', 'a', 'good', 'marvel', 'movie']
# Removed Punctuations: ['nothing', 'beats', 'a', 'good', 'marvel', 'movie', 'and', 'this', 'is', 'definitely', 'a', 'good', 'marvel', 'movie']
# Removed stopwords: ['nothing', 'beats', 'good', 'marvel', 'movie', 'definitely', 'good', 'marvel', 'movie']
# Lemmatization: ['nothing', 'beat', 'good', 'marvel', 'movie', 'definitely', 'good', 'marvel', 'movie']
# ==================================================
# After Lowercase : this movie did for marvel what wonder woman did for dc. captain marvel is a great role model for young children. great to see colson and fury as well. loved goose.
#
# Tokens : ['this', 'movie', 'did', 'for', 'marvel', 'what', 'wonder', 'woman', 'did', 'for', 'dc', '.', 'captain', 'marvel', 'is', 'a', 'great', 'role', 'model', 'for', 'young', 'children', '.', 'great', 'to', 'see', 'colson', 'and', 'fury', 'as', 'well', '.', 'loved', 'goose', '.']
# Removed Punctuations: ['this', 'movie', 'did', 'for', 'marvel', 'what', 'wonder', 'woman', 'did', 'for', 'dc', 'captain', 'marvel', 'is', 'a', 'great', 'role', 'model', 'for', 'young', 'children', 'great', 'to', 'see', 'colson', 'and', 'fury', 'as', 'well', 'loved', 'goose']
# Removed stopwords: ['movie', 'marvel', 'wonder', 'woman', 'dc', 'captain', 'marvel', 'great', 'role', 'model', 'young', 'children', 'great', 'see', 'colson', 'fury', 'well', 'loved', 'goose']
# Lemmatization: ['movie', 'marvel', 'wonder', 'woman', 'dc', 'captain', 'marvel', 'great', 'role', 'model', 'young', 'children', 'great', 'see', 'colson', 'fury', 'well', 'love', 'goose']
# ==================================================
# After Lowercase : captain marvel just became my favorite superhero of all time. this movie was funnier than i expected and all-around great. go see it!
#
# Tokens : ['captain', 'marvel', 'just', 'became', 'my', 'favorite', 'superhero', 'of', 'all', 'time', '.', 'this', 'movie', 'was', 'funnier', 'than', 'i', 'expected', 'and', 'all-around', 'great', '.', 'go', 'see', 'it', '!']
# Removed Punctuations: ['captain', 'marvel', 'just', 'became', 'my', 'favorite', 'superhero', 'of', 'all', 'time', 'this', 'movie', 'was', 'funnier', 'than', 'i', 'expected', 'and', 'all-around', 'great', 'go', 'see', 'it']
# Removed stopwords: ['captain', 'marvel', 'became', 'favorite', 'superhero', 'time', 'movie', 'funnier', 'expected', 'all-around', 'great', 'go', 'see']
# Lemmatization: ['captain', 'marvel', 'become', 'favorite', 'superhero', 'time', 'movie', 'funnier', 'expect', 'all-around', 'great', 'go', 'see']
# ==================================================
# After Lowercase : this is a very controversial marvel film. which seems to be a running trend with disney films recently.
#
# Tokens : ['this', 'is', 'a', 'very', 'controversial', 'marvel', 'film', '.', 'which', 'seems', 'to', 'be', 'a', 'running', 'trend', 'with', 'disney', 'films', 'recently', '.']
# Removed Punctuations: ['this', 'is', 'a', 'very', 'controversial', 'marvel', 'film', 'which', 'seems', 'to', 'be', 'a', 'running', 'trend', 'with', 'disney', 'films', 'recently']
# Removed stopwords: ['controversial', 'marvel', 'film', 'seems', 'running', 'trend', 'disney', 'films', 'recently']
# Lemmatization: ['controversial', 'marvel', 'film', 'seem', 'run', 'trend', 'disney', 'film', 'recently']
# ==================================================
# After Lowercase : unfortunately, despite carrying many elements of previous marvel installments, it fails to embody their success due to its questionable ambition.
#
# Tokens : ['unfortunately', ',', 'despite', 'carrying', 'many', 'elements', 'of', 'previous', 'marvel', 'installments', ',', 'it', 'fails', 'to', 'embody', 'their', 'success', 'due', 'to', 'its', 'questionable', 'ambition', '.']
# Removed Punctuations: ['unfortunately', 'despite', 'carrying', 'many', 'elements', 'of', 'previous', 'marvel', 'installments', 'it', 'fails', 'to', 'embody', 'their', 'success', 'due', 'to', 'its', 'questionable', 'ambition']
# Removed stopwords: ['unfortunately', 'despite', 'carrying', 'many', 'elements', 'previous', 'marvel', 'installments', 'fails', 'embody', 'success', 'due', 'questionable', 'ambition']
# Lemmatization: ['unfortunately', 'despite', 'carry', 'many', 'elements', 'previous', 'marvel', 'installments', 'fail', 'embody', 'success', 'due', 'questionable', 'ambition']
# ==================================================
# After Lowercase : it's worth watching just for the fact that this character will appear in the avangers infinity war part 2.
#
# Tokens : ['it', "'s", 'worth', 'watching', 'just', 'for', 'the', 'fact', 'that', 'this', 'character', 'will', 'appear', 'in', 'the', 'avangers', 'infinity', 'war', 'part', '2', '.']
# Removed Punctuations: ['it', "'s", 'worth', 'watching', 'just', 'for', 'the', 'fact', 'that', 'this', 'character', 'will', 'appear', 'in', 'the', 'avangers', 'infinity', 'war', 'part', '2']
# Removed stopwords: ["'s", 'worth', 'watching', 'fact', 'character', 'appear', 'avangers', 'infinity', 'war', 'part', '2']
# Lemmatization: ["'s", 'worth', 'watch', 'fact', 'character', 'appear', 'avangers', 'infinity', 'war', 'part', '2']
# ==================================================
# After Lowercase : it's great for a first time viewing. would you watch it again? nah. a good motivational for little kids with comical characters. first time viewing is good but i won't look back at it.
# Tokens : ['it', "'s", 'great', 'for', 'a', 'first', 'time', 'viewing', '.', 'would', 'you', 'watch', 'it', 'again', '?', 'nah', '.', 'a', 'good', 'motivational', 'for', 'little', 'kids', 'with', 'comical', 'characters', '.', 'first', 'time', 'viewing', 'is', 'good', 'but', 'i', 'wo', "n't", 'look', 'back', 'at', 'it', '.']
# Removed Punctuations: ['it', "'s", 'great', 'for', 'a', 'first', 'time', 'viewing', 'would', 'you', 'watch', 'it', 'again', 'nah', 'a', 'good', 'motivational', 'for', 'little', 'kids', 'with', 'comical', 'characters', 'first', 'time', 'viewing', 'is', 'good', 'but', 'i', 'wo', "n't", 'look', 'back', 'at', 'it']
# Removed stopwords: ["'s", 'great', 'first', 'time', 'viewing', 'would', 'watch', 'nah', 'good', 'motivational', 'little', 'kids', 'comical', 'characters', 'first', 'time', 'viewing', 'good', 'wo', "n't", 'look', 'back']
# Lemmatization: ["'s", 'great', 'first', 'time', 'view', 'would', 'watch', 'nah', 'good', 'motivational', 'little', 'kid', 'comical', 'character', 'first', 'time', 'view', 'good', 'wo', "n't", 'look', 'back']
# ==================================================

# %% [markdown]
# ##INTENT CLASSIFICATION

# %%
training_data = [
    ("hello", "greet"),
    ("hi there", "greet"),
    ("good morning", "greet"),
    ("hey","greet"),
    ("what's the weather today","weather"),
    ("tell me weather","weather"),
    ("is it raining","weather"),
    ("open","open_app"),
    ("open google","open_app"),
    ("open youtube","open_app"),
    ("bye","exit"),
    ("goodbye","exit")
]

# %%
sentences = []
labels = []

for text, intent in training_data:
    sentences.append(text)
    labels.append(intent)

# %%
import string
punc = string.punctuation

def preprocess_text(sentences):
    cleaned_sentences = []
    for sentence in sentences:
        text = sentence.lower()
        tokens = word_tokenize(text)
        punctuation_filter = [word for word in tokens if word not in punc]
        eng_stopwords = stopwords.words("english")
        filtered_tokens = [word for word in punctuation_filter if word not in eng_stopwords]
        wnet = WordNetLemmatizer()
        lemmatized_words = []
        for word in filtered_tokens:
            lemmatized_words.append(wnet.lemmatize(word,"v"))
        cleaned_text = " ".join(lemmatized_words)
        cleaned_sentences.append(cleaned_text)

    return cleaned_sentences

# %%
clean_data = preprocess_text(sentences)

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(clean_data)

# %%
logistic = LogisticRegression()
logistic.fit(X, labels)
# Out:
# LogisticRegression()

# %%
user_input = "hola"
processed = preprocess_text([user_input])
user_vector = vectorizer.transform(processed)
prediction = logistic.predict(user_vector)
print(prediction)
# Out:
# ['greet']
